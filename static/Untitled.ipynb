# %%
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
from sqlalchemy import func
import pandas as pd
import numpy as np

import json
import re

from flask import Flask, jsonify, render_template, request, redirect


rds_connection_string = "postgres:5Bottlesof#rum@127.0.0.1:5432/solar"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Confirmation that connection worked

tables = engine.table_names()
tables
# Out:
# ['solar_consumption', 'installed_solar_capacity']

# %%
session.close()
session = Session(engine)

# %%
solar_consumption.to_dict(orient="rows")
# Out:
# [{'entity': 'Africa', 'code': None, 'year': 1965, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1966, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1967, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1968, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1969, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1970, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1971, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1972, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1973, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1974, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1975, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1976, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1977, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1978, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1979, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1980, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1981, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1982, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1983, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1984, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1985, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1986, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1987, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1988, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1989, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1990, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1991, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1992, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1993, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1994, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1995, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1996, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1997, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1998, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa', 'code': None, 'year': 1999, 'solar_generation_twh': 0.0},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2000,
#   'solar_generation_twh': 0.0184},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2001,
#   'solar_generation_twh': 0.0247},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2002,
#   'solar_generation_twh': 0.03080101},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2003,
#   'solar_generation_twh': 0.03390101},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2004,
#   'solar_generation_twh': 0.03910101},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2005,
#   'solar_generation_twh': 0.04420101},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2006,
#   'solar_generation_twh': 0.05190101},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2007,
#   'solar_generation_twh': 0.063625293},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2008,
#   'solar_generation_twh': 0.084917202},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2009,
#   'solar_generation_twh': 0.107869927},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2010,
#   'solar_generation_twh': 0.22386475},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2011,
#   'solar_generation_twh': 0.460530301},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2012,
#   'solar_generation_twh': 0.553427126},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2013,
#   'solar_generation_twh': 0.824283141},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2014,
#   'solar_generation_twh': 1.826255884},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2015,
#   'solar_generation_twh': 3.568277276},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2016,
#   'solar_generation_twh': 4.911321327},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2017,
#   'solar_generation_twh': 6.610571458},
#  {'entity': 'Africa',
#   'code': None,
#   'year': 2018,
#   'solar_generation_twh': 9.029088999},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2004,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2005,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2006,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2007,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2008,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2009,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2010,
#   'solar_generation_twh': 0.0091},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2011,
#   'solar_generation_twh': 0.01811875},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2012,
#   'solar_generation_twh': 0.026723014},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2013,
#   'solar_generation_twh': 0.0286},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2014,
#   'solar_generation_twh': 0.06},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2015,
#   'solar_generation_twh': 0.058},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2016,
#   'solar_generation_twh': 0.245},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2017,
#   'solar_generation_twh': 0.504},
#  {'entity': 'Algeria',
#   'code': 'DZA',
#   'year': 2018,
#   'solar_generation_twh': 0.603},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1998,
#   'solar_generation_twh': 1.7e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 1999,
#   'solar_generation_twh': 2.6e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2000,
#   'solar_generation_twh': 3.6e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2001,
#   'solar_generation_twh': 4.3e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2002,
#   'solar_generation_twh': 4.7e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2003,
#   'solar_generation_twh': 6.5e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2004,
#   'solar_generation_twh': 7e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2005,
#   'solar_generation_twh': 8.1e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2006,
#   'solar_generation_twh': 9e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2007,
#   'solar_generation_twh': 0.0001089},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2008,
#   'solar_generation_twh': 0.0001437},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2009,
#   'solar_generation_twh': 7.6084e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2010,
#   'solar_generation_twh': 8.589e-05},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2011,
#   'solar_generation_twh': 0.001614},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2012,
#   'solar_generation_twh': 0.008172967},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2013,
#   'solar_generation_twh': 0.015074079},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2014,
#   'solar_generation_twh': 0.015944},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2015,
#   'solar_generation_twh': 0.014683},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2016,
#   'solar_generation_twh': 0.014273},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2017,
#   'solar_generation_twh': 0.016417},
#  {'entity': 'Argentina',
#   'code': 'ARG',
#   'year': 2018,
#   'solar_generation_twh': 0.108128528},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1990,
#   'solar_generation_twh': 0.004},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1991,
#   'solar_generation_twh': 0.00945},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1992,
#   'solar_generation_twh': 0.0276},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1993,
#   'solar_generation_twh': 0.0431},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1994,
#   'solar_generation_twh': 0.0534},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1995,
#   'solar_generation_twh': 0.070660101},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1996,
#   'solar_generation_twh': 0.098160606},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1997,
#   'solar_generation_twh': 0.147015452},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1998,
#   'solar_generation_twh': 0.202918856},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 1999,
#   'solar_generation_twh': 0.286266606},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2000,
#   'solar_generation_twh': 0.428429426},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2001,
#   'solar_generation_twh': 0.608465426},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2002,
#   'solar_generation_twh': 0.829254425},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2003,
#   'solar_generation_twh': 1.116542608},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2004,
#   'solar_generation_twh': 1.464055013},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2005,
#   'solar_generation_twh': 1.852813527},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2006,
#   'solar_generation_twh': 2.29127578},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2007,
#   'solar_generation_twh': 2.748580976},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2008,
#   'solar_generation_twh': 3.330602555},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2009,
#   'solar_generation_twh': 4.383497988},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2010,
#   'solar_generation_twh': 6.738748497},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2011,
#   'solar_generation_twh': 12.15439924},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2012,
#   'solar_generation_twh': 17.5830281},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2013,
#   'solar_generation_twh': 32.33890709},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2014,
#   'solar_generation_twh': 62.87474908},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2015,
#   'solar_generation_twh': 99.19372578},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2016,
#   'solar_generation_twh': 141.7552294},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2017,
#   'solar_generation_twh': 227.1966379},
#  {'entity': 'Asia Pacific',
#   'code': None,
#   'year': 2018,
#   'solar_generation_twh': 314.2085529},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1991,
#   'solar_generation_twh': 0.00545},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1992,
#   'solar_generation_twh': 0.0121},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1993,
#   'solar_generation_twh': 0.0146},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1994,
#   'solar_generation_twh': 0.0174},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1995,
#   'solar_generation_twh': 0.02115},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1996,
#   'solar_generation_twh': 0.0256},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1997,
#   'solar_generation_twh': 0.03065},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1998,
#   'solar_generation_twh': 0.0356},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 1999,
#   'solar_generation_twh': 0.0406},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2000,
#   'solar_generation_twh': 0.04675},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2001,
#   'solar_generation_twh': 0.05415},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2002,
#   'solar_generation_twh': 0.0583},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2003,
#   'solar_generation_twh': 0.0632},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2004,
#   'solar_generation_twh': 0.07295},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2005,
#   'solar_generation_twh': 0.08405},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2006,
#   'solar_generation_twh': 0.0975},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2007,
#   'solar_generation_twh': 0.11375},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2008,
#   'solar_generation_twh': 0.1392},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2009,
#   'solar_generation_twh': 0.29024203},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2010,
#   'solar_generation_twh': 0.97764828},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2011,
#   'solar_generation_twh': 2.04454657},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2012,
#   'solar_generation_twh': 2.412},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2013,
#   'solar_generation_twh': 3.8474},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2014,
#   'solar_generation_twh': 4.952},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2015,
#   'solar_generation_twh': 5.958},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2016,
#   'solar_generation_twh': 7.474595},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2017,
#   'solar_generation_twh': 8.95511},
#  {'entity': 'Australia',
#   'code': 'AUS',
#   'year': 2018,
#   'solar_generation_twh': 12.081099},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1993,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1994,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1995,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1996,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1997,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1998,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 1999,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2000,
#   'solar_generation_twh': 0.003},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2001,
#   'solar_generation_twh': 0.005},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2002,
#   'solar_generation_twh': 0.009},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2003,
#   'solar_generation_twh': 0.015},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2004,
#   'solar_generation_twh': 0.018},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2005,
#   'solar_generation_twh': 0.021018375},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2006,
#   'solar_generation_twh': 0.022386875},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2007,
#   'solar_generation_twh': 0.024238375},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2008,
#   'solar_generation_twh': 0.03011991},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2009,
#   'solar_generation_twh': 0.04891428},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2010,
#   'solar_generation_twh': 0.08881314},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2011,
#   'solar_generation_twh': 0.17406996},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2012,
#   'solar_generation_twh': 0.33748305},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2013,
#   'solar_generation_twh': 0.625974},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2014,
#   'solar_generation_twh': 0.785246},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2015,
#   'solar_generation_twh': 0.937098},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2016,
#   'solar_generation_twh': 1.096016},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2017,
#   'solar_generation_twh': 1.268971},
#  {'entity': 'Austria',
#   'code': 'AUT',
#   'year': 2018,
#   'solar_generation_twh': 1.578641473},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2004,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2005,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2006,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2007,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2008,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2009,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2010,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2011,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2012,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2013,
#   'solar_generation_twh': 0.0008},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2014,
#   'solar_generation_twh': 0.0029},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2015,
#   'solar_generation_twh': 0.0046},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2016,
#   'solar_generation_twh': 0.0353},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2017,
#   'solar_generation_twh': 0.0372},
#  {'entity': 'Azerbaijan',
#   'code': 'AZE',
#   'year': 2018,
#   'solar_generation_twh': 0.03926},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2002,
#   'solar_generation_twh': 0.0001},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2003,
#   'solar_generation_twh': 0.0009},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2004,
#   'solar_generation_twh': 0.0019},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2005,
#   'solar_generation_twh': 0.0034},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2006,
#   'solar_generation_twh': 0.0054},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2007,
#   'solar_generation_twh': 0.009},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2008,
#   'solar_generation_twh': 0.0152},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2009,
#   'solar_generation_twh': 0.0251},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2010,
#   'solar_generation_twh': 0.0443},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2011,
#   'solar_generation_twh': 0.0584},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2012,
#   'solar_generation_twh': 0.0909},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2013,
#   'solar_generation_twh': 0.1296},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2014,
#   'solar_generation_twh': 0.1676},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2015,
#   'solar_generation_twh': 0.2044},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2016,
#   'solar_generation_twh': 0.2243},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2017,
#   'solar_generation_twh': 0.265005663},
#  {'entity': 'Bangladesh',
#   'code': 'BGD',
#   'year': 2018,
#   'solar_generation_twh': 0.299208359},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2004,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2005,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2006,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2007,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2008,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2009,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2010,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2011,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2012,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2013,
#   'solar_generation_twh': 0.0004},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2014,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2015,
#   'solar_generation_twh': 0.009},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2016,
#   'solar_generation_twh': 0.026},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2017,
#   'solar_generation_twh': 0.089},
#  {'entity': 'Belarus',
#   'code': 'BLR',
#   'year': 2018,
#   'solar_generation_twh': 0.134485968},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2004,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2005,
#   'solar_generation_twh': 0.001},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2006,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2007,
#   'solar_generation_twh': 0.006},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2008,
#   'solar_generation_twh': 0.042},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2009,
#   'solar_generation_twh': 0.166},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2010,
#   'solar_generation_twh': 0.56},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2011,
#   'solar_generation_twh': 1.169},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2012,
#   'solar_generation_twh': 2.148},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2013,
#   'solar_generation_twh': 2.644},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2014,
#   'solar_generation_twh': 2.883},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2015,
#   'solar_generation_twh': 3.053},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2016,
#   'solar_generation_twh': 3.092},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2017,
#   'solar_generation_twh': 3.2876},
#  {'entity': 'Belgium',
#   'code': 'BEL',
#   'year': 2018,
#   'solar_generation_twh': 3.971724224},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Brazil',
#   'code': 'BRA',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
# ...
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2013,
#   'solar_generation_twh': 0.00675656},
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2014,
#   'solar_generation_twh': 0.48954159},
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2015,
#   'solar_generation_twh': 1.26108742},
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2016,
#   'solar_generation_twh': 2.638839211},
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2017,
#   'solar_generation_twh': 3.895948315},
#  {'entity': 'Chile',
#   'code': 'CHL',
#   'year': 2018,
#   'solar_generation_twh': 5.118720829},
#  {'entity': 'China', 'code': 'CHN', 'year': 1965, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1966, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1967, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1968, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1969, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1970, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1971, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1972, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1973, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1974, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1975, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1976, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1977, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1978, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1979, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1980, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1981, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1982, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1983, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1984, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1985, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1986, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1987, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1988, 'solar_generation_twh': 0.0},
#  {'entity': 'China', 'code': 'CHN', 'year': 1989, 'solar_generation_twh': 0.0},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1990,
#   'solar_generation_twh': 0.002},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1991,
#   'solar_generation_twh': 0.002},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1992,
#   'solar_generation_twh': 0.003},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1993,
#   'solar_generation_twh': 0.004},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1994,
#   'solar_generation_twh': 0.005},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1995,
#   'solar_generation_twh': 0.007},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1996,
#   'solar_generation_twh': 0.009},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1997,
#   'solar_generation_twh': 0.011},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1998,
#   'solar_generation_twh': 0.014},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 1999,
#   'solar_generation_twh': 0.017},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2000,
#   'solar_generation_twh': 0.022},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2001,
#   'solar_generation_twh': 0.031},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2002,
#   'solar_generation_twh': 0.048},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2003,
#   'solar_generation_twh': 0.064},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2004,
#   'solar_generation_twh': 0.076},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2005,
#   'solar_generation_twh': 0.084},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2006,
#   'solar_generation_twh': 0.095},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2007,
#   'solar_generation_twh': 0.114},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2008,
#   'solar_generation_twh': 0.152},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2009,
#   'solar_generation_twh': 0.279},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2010,
#   'solar_generation_twh': 0.701},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2011,
#   'solar_generation_twh': 2.61},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2012,
#   'solar_generation_twh': 3.5945099},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2013,
#   'solar_generation_twh': 8.3738865},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2014,
#   'solar_generation_twh': 23.51215664},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2015,
#   'solar_generation_twh': 43.56},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2016,
#   'solar_generation_twh': 61.686},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2017,
#   'solar_generation_twh': 117.8},
#  {'entity': 'China',
#   'code': 'CHN',
#   'year': 2018,
#   'solar_generation_twh': 177.5},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2000,
#   'solar_generation_twh': 0.001835014},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2001,
#   'solar_generation_twh': 0.00266875},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2002,
#   'solar_generation_twh': 0.00465125},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2003,
#   'solar_generation_twh': 0.006405},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2004,
#   'solar_generation_twh': 0.007951726},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2005,
#   'solar_generation_twh': 0.00953125},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2006,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2007,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2008,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2009,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2010,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2011,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2012,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2013,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2014,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2015,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2016,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2017,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Colombia',
#   'code': 'COL',
#   'year': 2018,
#   'solar_generation_twh': 0.011999821},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2004,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2005,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2006,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2007,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2008,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2009,
#   'solar_generation_twh': 1.6464e-05},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2010,
#   'solar_generation_twh': 1.6464e-05},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2011,
#   'solar_generation_twh': 1.6464e-05},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2012,
#   'solar_generation_twh': 0.002},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2013,
#   'solar_generation_twh': 0.011293959},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2014,
#   'solar_generation_twh': 0.035},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2015,
#   'solar_generation_twh': 0.057},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2016,
#   'solar_generation_twh': 0.066},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2017,
#   'solar_generation_twh': 0.0787},
#  {'entity': 'Croatia',
#   'code': 'HRV',
#   'year': 2018,
#   'solar_generation_twh': 0.073591668},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1965,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1966,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1967,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1968,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1969,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1970,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1971,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1972,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1973,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1974,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1975,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1976,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1977,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1978,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1979,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1980,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1981,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1982,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1983,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1984,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1985,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1986,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1987,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1988,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1989,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1990,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1991,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1992,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1993,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1994,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1995,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1996,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1997,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1998,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 1999,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 2000,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 2001,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 2002,
#   'solar_generation_twh': 0.0},
#  {'entity': 'Cyprus',
#   'code': 'CYP',
#   'year': 2003,
#   'solar_generation_twh': 0.0},
#  ...]

# %%
session = Session(engine)

solar_consumption = pd.read_sql_query('select * from solar_consumption', con=session.connection())
session.close()
solar_consumption.head()
# Out:
#    entity  code  year  solar_generation_twh
# 0  Africa  None  1965                   0.0
# 1  Africa  None  1966                   0.0
# 2  Africa  None  1967                   0.0
# 3  Africa  None  1968                   0.0
# 4  Africa  None  1969                   0.0

# %%
dir(engine)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_connection_cls',
#  '_contextual_connect',
#  '_echo',
#  '_execute_clauseelement',
#  '_execute_compiled',
#  '_execute_default',
#  '_execution_options',
#  '_has_events',
#  '_optional_conn_ctx_manager',
#  '_run_visitor',
#  '_should_log_debug',
#  '_should_log_info',
#  '_trans_ctx',
#  '_wrap_pool_connect',
#  'begin',
#  'connect',
#  'contextual_connect',
#  'create',
#  'dialect',
#  'dispatch',
#  'dispose',
#  'driver',
#  'drop',
#  'echo',
#  'engine',
#  'execute',
#  'execution_options',
#  'get_execution_options',
#  'has_table',
#  'hide_parameters',
#  'logger',
#  'logging_name',
#  'name',
#  'pool',
#  'raw_connection',
#  'run_callable',
#  'scalar',
#  'schema_for_object',
#  'table_names',
#  'transaction',
#  'update_execution_options',
#  'url']

# %%
pd.read_sql_query('select * from installed_solar_capacity', con=engine).head()

# %%
inspector = inspect(engine)
inspector.get_table_names()

# %%
#columns = inspector.get_columns('installed_solar_capacity')
#for c in columns:
#    print(c['name'], c["type"])

# %%
#engine.execute('SELECT * FROM installed_solar_capacity LIMIT 5').fetchall()

# %%
# Declare a Base using `automap_base()`
Base = automap_base()
Base
# Out:
# sqlalchemy.ext.automap.Base

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
Base

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# []

# %%
# Flask Setup
app = Flask(__name__)

# %%
# Flask Routes

# Return the dashboard homepage
@app.route("/")
def index():
    return render_template("index.html")

# Return the consumption page
@app.route("/consumption")
def consumption():
    return render_template("consumption.html")


# Return the capacity page
@app.route("/capacity")
def capacity():
    return render_template("capacity.html")
